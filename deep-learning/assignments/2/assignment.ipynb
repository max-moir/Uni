# %%
import assignment
from importlib import reload
#reloading allows "hotcode" swapping so the python runtime doesn't need to restart
reload(assignment)
assignment.main('./CIFAR_data/')

# %%
import unittest
unittest.main(module='assignment_tests', argv=[''], exit=False)
# Out:
# EEEEE
# ======================================================================
# ERROR: test_loss (assignment_tests.TestAssignment2.test_loss)
# Simple test to make sure loss function is the average softmax cross-entropy loss
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/csse/users/mmo199/Uni/deep-learning/assignments/2/assignment_tests.py", line 84, in test_loss
#     self.assertAlmostEqual(loss(logits, labels), 0.31326166)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/unittest/case.py", line 938, in assertAlmostEqual
#     diff = abs(first - second)
#                ~~~~~~^~~~~~~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'
#
# ======================================================================
# ERROR: test_same_0 (assignment_tests.TestAssignment2.test_same_0)
# Simple test using SAME padding to check out differences between
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/csse/users/mmo199/Uni/deep-learning/assignments/2/assignment_tests.py", line 25, in test_same_0
#     self.assertSequenceEqual(my_conv[0][0][0], tf_conv[0][0][0].numpy())
#                              ~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
#
# ======================================================================
# ERROR: test_valid_0 (assignment_tests.TestAssignment2.test_valid_0)
# Simple test using VALID padding to check out differences between
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/csse/users/mmo199/Uni/deep-learning/assignments/2/assignment_tests.py", line 43, in test_valid_0
#     self.assertSequenceEqual(my_conv[0][0], tf_conv[0][0].numpy())
#                              ~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
#
# ======================================================================
# ERROR: test_valid_1 (assignment_tests.TestAssignment2.test_valid_1)
# Simple test using VALID padding to check out differences between
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/csse/users/mmo199/Uni/deep-learning/assignments/2/assignment_tests.py", line 60, in test_valid_1
#     self.assertSequenceEqual(my_conv[0][0], tf_conv[0][0].numpy())
#                              ~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
#
# ======================================================================
# ERROR: test_valid_2 (assignment_tests.TestAssignment2.test_valid_2)
# Simple test using VALID padding to check out differences between
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/csse/users/mmo199/Uni/deep-learning/assignments/2/assignment_tests.py", line 74, in test_valid_2
#     self.assertSequenceEqual(my_conv[0][0], tf_conv[0][0].numpy())
#                              ~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.005s
#
# FAILED (errors=5)
